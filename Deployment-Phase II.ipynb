# %%
import pickle #import pickle lib

# %%
#Testing final model in deployment phase
loaded_model=pickle.load(open("finalized_model_linear.sav" 'rb')) #read the model
result=loaded_model.predict([[]]) #FFinal result
